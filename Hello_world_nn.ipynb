# %% [markdown]
# <a href="https://colab.research.google.com/github/srirampattabiraman/coursera_tensorflow/blob/main/Hello_world_nn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
##Defining nn
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
##Defining data
x = np.array([-1.0, 0,1,2,3,4], dtype=float)
y = np.array([-3.0, -1,1,3,5,7], dtype=float)

# %%
model.fit(x, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 2.8359
# Epoch 2/500
# 1/1 [==============================] - 0s 3ms/step - loss: 2.4483
# Epoch 3/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.1389
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.8912
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.6919
# Epoch 6/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.5310
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.4003
# Epoch 8/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2934
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 1.2054
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.1323
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0710
# Epoch 12/500
# 1/1 [==============================] - 0s 2ms/step - loss: 1.0191
# ...

# %%
model.predict([9, 10])
# Out:
# array([[16.98507 ],
#        [18.982538]], dtype=float32)
